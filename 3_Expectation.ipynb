# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import cauchy

# %%
n=10000

i=np.arange(1,n+1)
norm_xi=np.random.randn(n)
norm_mean=np.cumsum(norm_xi)/i

plt.plot(i,norm_mean)
plt.show()

# %%
cauchy_xi = cauchy.rvs(size=n)
cauchy_mean = np.cumsum(cauchy_xi)/i

plt.plot(i,cauchy_mean)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
n = 10000
m=10

i=np.arange(1,n+1)
yi = np.random.choice([-1, 1], p=[0.5, 0.5], size=(m,n))
xis=np.cumsum(yi, axis=1)

for xi in xis:
    plt.plot(i, xi)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=np.linspace(-1,2,1000)
y=(x<1)*(x>0)

# %%
plt.plot(x,y)

# %%
import seaborn as sns

# %%
m=10000
ns = [1,5,25,100]
means=[]
vars=[]


for n in range(1, 101):
    xis=np.random.uniform(0,1,size=(m,n))
    mean=np.sum(xis, axis = 1)/n
    means.append(np.mean(mean))
    vars.append(np.var(mean))

    if n in ns:
        print("n = {}, mean = {}, variance in mean = {}".format(n, np.mean(mean), np.var(mean)))
        sns.histplot(mean, stat='density')

plt.xlabel('Xbar')
plt.show()
# Out:
# n = 1, mean = 0.5030099329715662, variance in mean = 0.08248904650190382
# n = 5, mean = 0.4991599225399607, variance in mean = 0.016501170906151948
# n = 25, mean = 0.5000734542814055, variance in mean = 0.0033271855520682196
# n = 100, mean = 0.49973801671804574, variance in mean = 0.000847384773088296

# %%
i = np.arange(1,101)

plt.plot(i,means)
plt.xlabel('n')
plt.ylabel('average of Xbar')
plt.show()

plt.plot(i, 1 / (12 * i), label = 'calculated')
plt.plot(i, vars, label = 'measured')
plt.yscale('log')
plt.xlabel('n')
plt.ylabel('variance of xbar')
plt.legend()

plt.show()
